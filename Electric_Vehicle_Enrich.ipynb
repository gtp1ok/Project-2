# %% [markdown]
# # Extract Transform Load (ETL)
#
# Extract:
# Extract the Electric Vehicle data for Washington State for further analysis. Extracted the Data for the Electric Vehicle Title and Registration Activity for Washington State from data.wa.gov  in the form of CSV file. To enrich the data we got in the  form of csv file we made API call to data.wa.gov and got DOL Vehicle ID ,Clean Alternative Fuel Vehicle (CAFV) Eligibility and Electric Utility for Washington State.
#
# Clean Alternative Fuel Vehicle (CAFV) Eligibility- This categorizes vehicle as Clean Alternative Fuel Vehicles (CAFVs) based on the fuel requirement and electric-only range requirement in House Bill 2042 as passed in the 2019 legislative session.
#
# Electric Utility -This is the electric power retail service territories serving the address of the registered vehicle.
#
# DOL Vehicle ID- A unique identification number for each vehicle present in Transactions dataset. Transactions done on the same vehicle will have the same DOL Vehicle ID.
#
# Transform:
# Used the pandas to convert the CSV file data and API call data into dataframe and performed following steps to clean the data:
# -Dropped the columns which we don’t require for further analysis.
# -Filtered the data by transaction type is equal to Original Registration and transaction year is greater or equal to 2020.
# -Outer Joined the two dataframe using DOL Vehicle ID.
#
# Load:
# Loaded data  into Mongo DB

# %%
import pandas as pd
import requests
from pprint import pprint
import pymongo

# %%
df = pd.read_csv('Resources/Electric_Vehicle_Title_and_Registration_Activity.csv')
#df.head()
df.columns
#df.describe()
# Out:
# Index(['Clean Alternative Fuel Vehicle Type', 'VIN (1-10)', 'Model Year',
#        'Make', 'Model', 'New or Used Vehicle', 'Sale Price',
#        'DOL Transaction Date', 'Transaction Type', 'Transaction Year',
#        'Electric Vehicle Fee Paid', 'County', 'City', 'Postal Code',
#        'Electric Range', 'Base MSRP', '2015 HB 2778 Exemption Eligibility',
#        'Sale Date', 'Vehicle Primary Use', 'State of Residence',
#        'DOL Vehicle ID', 'Legislative District',
#        '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#        'Meets 2019 HB 2042 Electric Range Requirement',
#        'Meets 2019 HB 2042 Sale Date Requirement',
#        'Meets 2019 HB 2042 Sale Price/Value Requirement', 'Odometer Reading',
#        'Odometer Code', 'Transportation Electrification Fee Paid',
#        'Hybrid Vehicle Electrification Fee Paid', '2020 Census Tract'],
#       dtype='object')

# %%
# selecting all rows from given dataframe in which transaction type is equal to  Original Registration 
#and transaction year is greater or equal to 2020

df = df[(df['Transaction Type'] == 'Original Registration') & (df['Transaction Year'] >= 2020)]
df
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  Model Year  \
# 14          Battery Electric Vehicle (BEV)  5YJ3E1EC9N        2022
# 36          Battery Electric Vehicle (BEV)  1N4CZ1CV4P        2023
# 40          Battery Electric Vehicle (BEV)  5YJ3E1EB0N        2022
# 53          Battery Electric Vehicle (BEV)  1G1FY6S03L        2020
# 77          Battery Electric Vehicle (BEV)  YV4ED3UR6N        2022
# ...                                    ...         ...         ...
# 617674      Battery Electric Vehicle (BEV)  1N4BZ1BV9N        2022
# 617677      Battery Electric Vehicle (BEV)  WVGGNPE20N        2022
# 617679      Battery Electric Vehicle (BEV)  5YJ3E1EBXN        2022
# 617687      Battery Electric Vehicle (BEV)  5YJ3E1EA0N        2022
# 617689      Battery Electric Vehicle (BEV)  5YJYGDEF9L        2020
#
#               Make    Model New or Used Vehicle  Sale Price  \
# 14           TESLA  Model 3                 New           0
# 36          NISSAN     Leaf                 New           0
# 40           TESLA  Model 3                 New           0
# 53       CHEVROLET  Bolt EV                 New           0
# 77           VOLVO     XC40                 New           0
# ...            ...      ...                 ...         ...
# 617674      NISSAN     Leaf                 New           0
# 617677  VOLKSWAGEN     ID.4                 New           0
# 617679       TESLA  Model 3                 New           0
# 617687       TESLA  Model 3                 New           0
# 617689       TESLA  Model Y                 New           0
#
#        DOL Transaction Date       Transaction Type  Transaction Year  ...  \
# 14          October 28 2022  Original Registration              2022  ...
# 36          October 20 2022  Original Registration              2022  ...
# 40          October 11 2022  Original Registration              2022  ...
# 53          October 19 2020  Original Registration              2020  ...
# 77         November 24 2021  Original Registration              2021  ...
# ...                     ...                    ...               ...  ...
# 617674     December 13 2021  Original Registration              2021  ...
# 617677    September 07 2022  Original Registration              2022  ...
# 617679     February 10 2022  Original Registration              2022  ...
# 617687     February 18 2022  Original Registration              2022  ...
# 617689    September 09 2020  Original Registration              2020  ...
#
#        Legislative District  \
# 14                     41.0
# 36                     47.0
# 40                     45.0
# 53                      1.0
# 77                     48.0
# ...                     ...
# 617674                  9.0
# 617677                  2.0
# 617679                 38.0
# 617687                  1.0
# 617689                 33.0
#
#        2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# 14      ERROR: No battery range; TRANSACTION NOT ELIGI...
# 36      ERROR: No battery range; TRANSACTION NOT ELIGI...
# 40      ERROR: No battery range; TRANSACTION NOT ELIGI...
# 53      TRANSACTION NOT ELIGIBLE: Non-sale, registrati...
# 77      ERROR: No battery range; TRANSACTION NOT ELIGI...
# ...                                                   ...
# 617674  ERROR: No battery range; TRANSACTION NOT ELIGI...
# 617677  ERROR: No battery range; TRANSACTION NOT ELIGI...
# 617679  ERROR: No battery range; TRANSACTION NOT ELIGI...
# 617687  ERROR: No battery range; TRANSACTION NOT ELIGI...
# 617689  TRANSACTION NOT ELIGIBLE: Non-sale, registrati...
#
#        Meets 2019 HB 2042 Electric Range Requirement  \
# 14                                             False
# 36                                             False
# 40                                             False
# 53                                              True
# 77                                             False
# ...                                              ...
# 617674                                         False
# 617677                                         False
# 617679                                         False
# 617687                                         False
# 617689                                          True
#
#         Meets 2019 HB 2042 Sale Date Requirement  \
# 14                                         False
# 36                                         False
# 40                                         False
# 53                                         False
# 77                                         False
# ...                                          ...
# 617674                                     False
# 617677                                     False
# 617679                                     False
# 617687                                     False
# 617689                                     False
#
#         Meets 2019 HB 2042 Sale Price/Value Requirement  Odometer Reading  \
# 14                                                False                 0
# 36                                                False                 0
# 40                                                False                 0
# 53                                                False                 0
# 77                                                False                 0
# ...                                                 ...               ...
# 617674                                            False                 0
# 617677                                            False                 0
# 617679                                            False                 0
# 617687                                            False                 0
# 617689                                            False                 0
#
#                                             Odometer Code  \
# 14      Odometer reading is not collected at time of r...
# 36      Odometer reading is not collected at time of r...
# 40      Odometer reading is not collected at time of r...
# 53      Odometer reading is not collected at time of r...
# 77      Odometer reading is not collected at time of r...
# ...                                                   ...
# 617674  Odometer reading is not collected at time of r...
# 617677  Odometer reading is not collected at time of r...
# 617679  Odometer reading is not collected at time of r...
# 617687  Odometer reading is not collected at time of r...
# 617689  Odometer reading is not collected at time of r...
#
#        Transportation Electrification Fee Paid  \
# 14                                          No
# 36                                          No
# 40                                          No
# 53                                          No
# 77                                          No
# ...                                        ...
# 617674                                      No
# 617677                                      No
# 617679                                      No
# 617687                                      No
# 617689                                      No
#
#        Hybrid Vehicle Electrification Fee Paid 2020 Census Tract
# 14                                          No      5.303302e+10
# 36                                          No      5.303303e+10
# 40                                          No      5.303302e+10
# 53                                          No      5.303302e+10
# 77                                          No      5.303302e+10
# ...                                        ...               ...
# 617674                                      No      5.302102e+10
# 617677                                      No      5.305307e+10
# 617679                                      No      5.306104e+10
# 617687                                      No      5.303302e+10
# 617689                                      No      5.303303e+10
#
# [69246 rows x 31 columns]

# %%
# dropped the columns to clean up the data.
clean_df = df.drop(['New or Used Vehicle','Sale Price','Electric Vehicle Fee Paid','2015 HB 2778 Exemption Eligibility','Base MSRP','Sale Date','2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility','Meets 2019 HB 2042 Electric Range Requirement','Meets 2019 HB 2042 Sale Date Requirement','Meets 2019 HB 2042 Sale Price/Value Requirement','Hybrid Vehicle Electrification Fee Paid','2020 Census Tract', 'Odometer Reading',
       'Odometer Code'], axis=1)
clean_df
# Out:
#        Clean Alternative Fuel Vehicle Type  VIN (1-10)  Model Year  \
# 14          Battery Electric Vehicle (BEV)  5YJ3E1EC9N        2022
# 36          Battery Electric Vehicle (BEV)  1N4CZ1CV4P        2023
# 40          Battery Electric Vehicle (BEV)  5YJ3E1EB0N        2022
# 53          Battery Electric Vehicle (BEV)  1G1FY6S03L        2020
# 77          Battery Electric Vehicle (BEV)  YV4ED3UR6N        2022
# ...                                    ...         ...         ...
# 617674      Battery Electric Vehicle (BEV)  1N4BZ1BV9N        2022
# 617677      Battery Electric Vehicle (BEV)  WVGGNPE20N        2022
# 617679      Battery Electric Vehicle (BEV)  5YJ3E1EBXN        2022
# 617687      Battery Electric Vehicle (BEV)  5YJ3E1EA0N        2022
# 617689      Battery Electric Vehicle (BEV)  5YJYGDEF9L        2020
#
#               Make    Model DOL Transaction Date       Transaction Type  \
# 14           TESLA  Model 3      October 28 2022  Original Registration
# 36          NISSAN     Leaf      October 20 2022  Original Registration
# 40           TESLA  Model 3      October 11 2022  Original Registration
# 53       CHEVROLET  Bolt EV      October 19 2020  Original Registration
# 77           VOLVO     XC40     November 24 2021  Original Registration
# ...            ...      ...                  ...                    ...
# 617674      NISSAN     Leaf     December 13 2021  Original Registration
# 617677  VOLKSWAGEN     ID.4    September 07 2022  Original Registration
# 617679       TESLA  Model 3     February 10 2022  Original Registration
# 617687       TESLA  Model 3     February 18 2022  Original Registration
# 617689       TESLA  Model Y    September 09 2020  Original Registration
#
#         Transaction Year     County         City  Postal Code  Electric Range  \
# 14                  2022       King     BELLEVUE      98006.0               0
# 36                  2022       King       AUBURN      98092.0               0
# 40                  2022       King  WOODINVILLE      98072.0               0
# 53                  2020       King     KIRKLAND      98034.0             259
# 77                  2021       King     KIRKLAND      98033.0               0
# ...                  ...        ...          ...          ...             ...
# 617674              2021   Franklin        PASCO      99301.0               0
# 617677              2022     Pierce     PUYALLUP      98375.0               0
# 617679              2022  Snohomish      EVERETT      98201.0               0
# 617687              2022       King     KIRKLAND      98034.0               0
# 617689              2020       King         KENT      98030.0             291
#
#        Vehicle Primary Use State of Residence  DOL Vehicle ID  \
# 14               Passenger                 WA       219181686
# 36               Passenger                 WA       224487602
# 40               Passenger                 WA       217970987
# 53               Passenger                 WA       125985527
# 77               Passenger                 WA       180098852
# ...                    ...                ...             ...
# 617674           Passenger                 WA       186000923
# 617677           Passenger                 WA       212075832
# 617679           Passenger                 WA       190060069
# 617687           Passenger                 WA       192455651
# 617689           Passenger                 WA       118036621
#
#         Legislative District Transportation Electrification Fee Paid
# 14                      41.0                                      No
# 36                      47.0                                      No
# 40                      45.0                                      No
# 53                       1.0                                      No
# 77                      48.0                                      No
# ...                      ...                                     ...
# 617674                   9.0                                      No
# 617677                   2.0                                      No
# 617679                  38.0                                      No
# 617687                   1.0                                      No
# 617689                  33.0                                      No
#
# [69246 rows x 17 columns]

# %%
# left_df = clean_df

# %%
# https://data.wa.gov/resource/f6w7-q2d2.json?dol_vehicle_id=1908966
url = "https://data.wa.gov/resource/f6w7-q2d2.json?"
def get_cafv_utility(limit):
    query_url = 'https://data.wa.gov/resource/f6w7-q2d2.json?$select=dol_vehicle_id,cafv_type,electric_utility&$limit=' + str(limit)
    response = requests.get(query_url)
    if not response.ok:
        return None
        
    response = response.json()
    print(type(response))
    return pd.DataFrame(response)

df = get_cafv_utility(110000)
# df = df[df['dol_vehicle_id'].isin(['200589147','219181686', '224487602'])]
df['dol_vehicle_id'] = df['dol_vehicle_id'].astype(int)
# Out:
# <class 'list'>

# %%
merged_df=pd.merge(clean_df,df,left_on='DOL Vehicle ID', right_on='dol_vehicle_id',how='left')

# %%
#Uploading The Pandas DataFrame to MongoDB
# Convert dataframe to dictinary
merged_dict=merged_df.to_dict("records")
merged_dict
# Out:
# [{'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EC9N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'October 28 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98006.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 219181686,
#   'Legislative District': 41.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 219181686.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4CZ1CV4P',
#   'Model Year': 2023,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'October 20 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'AUBURN',
#   'Postal Code': 98092.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 224487602,
#   'Legislative District': 47.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 224487602.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB0N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'October 11 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 217970987,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 217970987.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1G1FY6S03L',
#   'Model Year': 2020,
#   'Make': 'CHEVROLET',
#   'Model': 'Bolt EV',
#   'DOL Transaction Date': 'October 19 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'KIRKLAND',
#   'Postal Code': 98034.0,
#   'Electric Range': 259,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 125985527,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 125985527.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'YV4ED3UR6N',
#   'Model Year': 2022,
#   'Make': 'VOLVO',
#   'Model': 'XC40',
#   'DOL Transaction Date': 'November 24 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'KIRKLAND',
#   'Postal Code': 98033.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 180098852,
#   'Legislative District': 48.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 180098852.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EA7K',
#   'Model Year': 2019,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'December 01 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98101.0,
#   'Electric Range': 220,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 139778985,
#   'Legislative District': 43.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 139778985.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'JN1AZ0CP6C',
#   'Model Year': 2012,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'May 04 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98133.0,
#   'Electric Range': 73,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 151643341,
#   'Legislative District': 32.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 151643341.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1G1FY6S03N',
#   'Model Year': 2022,
#   'Make': 'CHEVROLET',
#   'Model': 'Bolt EV',
#   'DOL Transaction Date': 'July 20 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98105.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 209436580,
#   'Legislative District': 43.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 209436580.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EBXL',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'April 07 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'ISSAQUAH',
#   'Postal Code': 98027.0,
#   'Electric Range': 322,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 104694495,
#   'Legislative District': 5.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 104694495.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJXCAE29L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model X',
#   'DOL Transaction Date': 'January 22 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'Snohomish',
#   'City': 'LAKE STEVENS',
#   'Postal Code': 98258.0,
#   'Electric Range': 293,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 2042435,
#   'Legislative District': 39.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 2042435.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJXCAE29L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model X',
#   'DOL Transaction Date': 'November 02 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'AUBURN',
#   'Postal Code': 98092.0,
#   'Electric Range': 293,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 127387123,
#   'Legislative District': 47.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAXCBE68N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model X',
#   'DOL Transaction Date': 'October 28 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'AUBURN',
#   'Postal Code': 98092.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 219000323,
#   'Legislative District': 47.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 219000323.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'KNDCE3LGXL',
#   'Model Year': 2020,
#   'Make': 'KIA',
#   'Model': 'Niro',
#   'DOL Transaction Date': 'April 01 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98006.0,
#   'Electric Range': 239,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 144797901,
#   'Legislative District': 41.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 144797901.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB8L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'March 25 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98006.0,
#   'Electric Range': 322,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 103581243,
#   'Legislative District': 41.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 103581243.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'YV4H60DZ0N',
#   'Model Year': 2022,
#   'Make': 'VOLVO',
#   'Model': 'XC60',
#   'DOL Transaction Date': 'June 17 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'RENTON',
#   'Postal Code': 98056.0,
#   'Electric Range': 35,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 207016190,
#   'Legislative District': 11.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 207016190.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEE3N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'July 06 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98006.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 204131924,
#   'Legislative District': 41.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 204131924.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEF6L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'July 30 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'REDMOND',
#   'Postal Code': 98052.0,
#   'Electric Range': 291,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 110837912,
#   'Legislative District': 48.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': '5UXTS1C03M',
#   'Model Year': 2021,
#   'Make': 'BMW',
#   'Model': 'X3',
#   'DOL Transaction Date': 'May 03 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98105.0,
#   'Electric Range': 17,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 198800108,
#   'Legislative District': 43.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 198800108.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'LPSED3KA8N',
#   'Model Year': 2022,
#   'Make': 'POLESTAR',
#   'Model': 'PS2',
#   'DOL Transaction Date': 'February 24 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Thurston',
#   'City': 'YELM',
#   'Postal Code': 98597.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 193454292,
#   'Legislative District': 2.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 193454292.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE2M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'February 18 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'AUBURN',
#   'Postal Code': 98001.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 142863808,
#   'Legislative District': 47.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 142863808.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'JHMZC5F12J',
#   'Model Year': 2018,
#   'Make': 'HONDA',
#   'Model': 'Clarity',
#   'DOL Transaction Date': 'April 21 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'BOTHELL',
#   'Postal Code': 98011.0,
#   'Electric Range': 47,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 199357329,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 199357329.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEF5N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'December 10 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BOTHELL',
#   'Postal Code': 98011.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 183031460,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 183031460.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB2M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'January 26 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BOTHELL',
#   'Postal Code': 98011.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 140325244,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 140325244.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EBXL',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'October 21 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'BOTHELL',
#   'Postal Code': 98011.0,
#   'Electric Range': 322,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 127128963,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE8L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'November 10 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'BOTHELL',
#   'Postal Code': 98011.0,
#   'Electric Range': 291,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 127082147,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 127082147.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '3FMTK3SU8M',
#   'Model Year': 2021,
#   'Make': 'FORD',
#   'Model': 'Mustang Mach-E',
#   'DOL Transaction Date': 'September 20 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Cowlitz',
#   'City': 'KELSO',
#   'Postal Code': 98626.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 177621699,
#   'Legislative District': 20.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 177621699.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF COWLITZ COUNTY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'KM8K33AG5L',
#   'Model Year': 2020,
#   'Make': 'HYUNDAI',
#   'Model': 'Kona',
#   'DOL Transaction Date': 'January 29 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'SHORELINE',
#   'Postal Code': 98155.0,
#   'Electric Range': 258,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 100827646,
#   'Legislative District': 32.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'WBY1Z8C58H',
#   'Model Year': 2017,
#   'Make': 'BMW',
#   'Model': 'i3',
#   'DOL Transaction Date': 'August 01 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98115.0,
#   'Electric Range': 97,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 211437999,
#   'Legislative District': 43.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 211437999.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAXCBE66N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model X',
#   'DOL Transaction Date': 'August 11 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 209561348,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 209561348.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '3FMTK3SU9M',
#   'Model Year': 2021,
#   'Make': 'FORD',
#   'Model': 'Mustang Mach-E',
#   'DOL Transaction Date': 'July 08 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98008.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 156822417,
#   'Legislative District': 48.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 156822417.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EA1M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'August 25 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Thurston',
#   'City': 'OLYMPIA',
#   'Postal Code': 98512.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 176430600,
#   'Legislative District': 22.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 176430600.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB6N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'February 08 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98007.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 193072841,
#   'Legislative District': 48.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 193072841.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB0L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'January 24 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'BELLEVUE',
#   'Postal Code': 98007.0,
#   'Electric Range': 322,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 9882204,
#   'Legislative District': 48.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EA9L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'October 13 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98122.0,
#   'Electric Range': 266,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 127119254,
#   'Legislative District': 43.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 127119254.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJSA1E56M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model S',
#   'DOL Transaction Date': 'December 23 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'LAKE FOREST PARK',
#   'Postal Code': 98155.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 183484563,
#   'Legislative District': 46.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 183484563.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE3M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'December 31 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'ISSAQUAH',
#   'Postal Code': 98029.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 136832377,
#   'Legislative District': 5.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 136832377.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4AZ1CVXN',
#   'Model Year': 2022,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'June 02 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'SNOHOMISH',
#   'Postal Code': 98290.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 203882780,
#   'Legislative District': 39.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 203882780.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOHOMISH COUNTY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE5L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'November 02 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98122.0,
#   'Electric Range': 291,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 127198515,
#   'Legislative District': 37.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 127198515.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '3FMTK3SU4M',
#   'Model Year': 2021,
#   'Make': 'FORD',
#   'Model': 'Mustang Mach-E',
#   'DOL Transaction Date': 'March 26 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98012.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 146812480,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 146812480.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EA8L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'January 22 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'ENUMCLAW',
#   'Postal Code': 98022.0,
#   'Electric Range': 266,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 8211885,
#   'Legislative District': 31.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 8211885.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE9M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'September 15 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BURIEN',
#   'Postal Code': 98166.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 175399087,
#   'Legislative District': 34.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 175399087.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': '3MW5P9J07M',
#   'Model Year': 2021,
#   'Make': 'BMW',
#   'Model': '330e',
#   'DOL Transaction Date': 'April 28 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'NORMANDY PARK',
#   'Postal Code': 98166.0,
#   'Electric Range': 20,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 150157101,
#   'Legislative District': 33.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 150157101.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'WP0CD2Y13N',
#   'Model Year': 2022,
#   'Make': 'PORSCHE',
#   'Model': 'Taycan',
#   'DOL Transaction Date': 'May 06 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'SNOHOMISH',
#   'Postal Code': 98290.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 203679913,
#   'Legislative District': 39.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 203679913.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4BZ1CV6N',
#   'Model Year': 2022,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'October 04 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98116.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 179066954,
#   'Legislative District': 34.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 179066954.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE7M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'October 15 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98012.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 179390823,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 179390823.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE7M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'February 18 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BOTHELL',
#   'Postal Code': 98011.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 141964014,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 141964014.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEF7N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'July 19 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98199.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 205616127,
#   'Legislative District': 36.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 205616127.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'LPSED3KA8N',
#   'Model Year': 2022,
#   'Make': 'POLESTAR',
#   'Model': 'PS2',
#   'DOL Transaction Date': 'January 25 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'RENTON',
#   'Postal Code': 98056.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 190314855,
#   'Legislative District': 11.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 190314855.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGAEE2N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'May 26 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'MAPLE VALLEY',
#   'Postal Code': 98038.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 202045903,
#   'Legislative District': 5.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 202045903.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'WMWXP3C0XM',
#   'Model Year': 2021,
#   'Make': 'MINI',
#   'Model': 'Hardtop',
#   'DOL Transaction Date': 'October 08 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'Clark',
#   'City': 'RIDGEFIELD',
#   'Postal Code': 98642.0,
#   'Electric Range': 110,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 128796958,
#   'Legislative District': 18.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 128796958.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': '5UXKT0C34H',
#   'Model Year': 2017,
#   'Make': 'BMW',
#   'Model': 'X5',
#   'DOL Transaction Date': 'March 17 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98117.0,
#   'Electric Range': 14,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 150067375,
#   'Legislative District': 36.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 150067375.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'YV4BC0PL6H',
#   'Model Year': 2017,
#   'Make': 'VOLVO',
#   'Model': 'XC90',
#   'DOL Transaction Date': 'April 14 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98117.0,
#   'Electric Range': 14,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 195166583,
#   'Legislative District': 36.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 195166583.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4AZ0CP4D',
#   'Model Year': 2013,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'March 07 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Clark',
#   'City': 'CAMAS',
#   'Postal Code': 98607.0,
#   'Electric Range': 75,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 195399522,
#   'Legislative District': 18.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 195399522.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLARK COUNTY - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE7M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'January 26 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'BLACK DIAMOND',
#   'Postal Code': 98010.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 138495605,
#   'Legislative District': 5.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 138495605.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGAEE9M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'April 09 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'MERCER ISLAND',
#   'Postal Code': 98040.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 148342890,
#   'Legislative District': 41.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 148342890.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB4N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'January 14 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'MAPLE VALLEY',
#   'Postal Code': 98038.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 185658182,
#   'Legislative District': 5.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 185658182.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EA7M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'July 22 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'COVINGTON',
#   'Postal Code': 98042.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 166169937,
#   'Legislative District': 47.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 166169937.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEE8N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'July 12 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SAMMAMISH',
#   'Postal Code': 98075.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 207189090,
#   'Legislative District': 41.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 207189090.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4AZ1BV1N',
#   'Model Year': 2022,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'January 12 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98021.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 183187273,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 183187273.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEF7N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'July 19 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'MAPLE VALLEY',
#   'Postal Code': 98038.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 207096683,
#   'Legislative District': 5.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 207096683.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': '2C4RC1S76M',
#   'Model Year': 2021,
#   'Make': 'CHRYSLER',
#   'Model': 'Pacifica',
#   'DOL Transaction Date': 'September 06 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98103.0,
#   'Electric Range': 32,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 216957793,
#   'Legislative District': 43.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 216957793.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': '3FA6P0PUXG',
#   'Model Year': 2016,
#   'Make': 'FORD',
#   'Model': 'Fusion',
#   'DOL Transaction Date': 'January 27 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98021.0,
#   'Electric Range': 19,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 4701294,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 4701294.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'WMW13DJ06P',
#   'Model Year': 2023,
#   'Make': 'MINI',
#   'Model': 'Hardtop',
#   'DOL Transaction Date': 'October 03 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98115.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 218845728,
#   'Legislative District': 46.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 218845728.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1FT6W1EV8N',
#   'Model Year': 2022,
#   'Make': 'FORD',
#   'Model': 'F-150',
#   'DOL Transaction Date': 'July 20 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98021.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Truck',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 208402078,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 208402078.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEF3N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'June 28 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98121.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 204129740,
#   'Legislative District': 36.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 204129740.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGDEE6L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'November 13 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'SEATTLE',
#   'Postal Code': 98121.0,
#   'Electric Range': 291,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 128886054,
#   'Legislative District': 36.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 128886054.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
# ...
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '3C3CFFGEXF',
#   'Model Year': 2015,
#   'Make': 'FIAT',
#   'Model': '500',
#   'DOL Transaction Date': 'August 01 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Spokane',
#   'City': 'SPOKANE',
#   'Postal Code': 99224.0,
#   'Electric Range': 87,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 213525364,
#   'Legislative District': 6.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 213525364.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'MODERN ELECTRIC WATER COMPANY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB6M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'July 28 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Grays Harbor',
#   'City': 'MONTESANO',
#   'Postal Code': 98563.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 169157901,
#   'Legislative District': 19.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 169157901.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF GRAYS HARBOR COUNTY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJXCDE21L',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model X',
#   'DOL Transaction Date': 'November 13 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 289,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 127249475,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 127249475.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'WA1F2AFY7M',
#   'Model Year': 2021,
#   'Make': 'AUDI',
#   'Model': 'Q5 e',
#   'DOL Transaction Date': 'June 22 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 18,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 154891488,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 154891488.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4BZ0CP5H',
#   'Model Year': 2017,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'August 27 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'Okanogan',
#   'City': 'OMAK',
#   'Postal Code': 98841.0,
#   'Electric Range': 107,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 124670304,
#   'Legislative District': 7.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 124670304.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUD NO 1 OF OKANOGAN COUNTY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJSA1E24J',
#   'Model Year': 2018,
#   'Make': 'TESLA',
#   'Model': 'Model S',
#   'DOL Transaction Date': 'March 18 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'MARYSVILLE',
#   'Postal Code': 98271.0,
#   'Electric Range': 249,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 196659683,
#   'Legislative District': 38.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 196659683.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJXCDE2XL',
#   'Model Year': 2020,
#   'Make': 'TESLA',
#   'Model': 'Model X',
#   'DOL Transaction Date': 'January 07 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'King',
#   'City': 'REDMOND',
#   'Postal Code': 98053.0,
#   'Electric Range': 289,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 6096814,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 6096814.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJSA1E54N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model S',
#   'DOL Transaction Date': 'September 07 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'REDMOND',
#   'Postal Code': 98053.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 211309913,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 211309913.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB3M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'April 07 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98021.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 148764801,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 148764801.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJYGAEEXM',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'October 26 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'RENTON',
#   'Postal Code': 98058.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 179002946,
#   'Legislative District': 11.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB6K',
#   'Model Year': 2019,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'September 21 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Clark',
#   'City': 'VANCOUVER',
#   'Postal Code': 98664.0,
#   'Electric Range': 220,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 175407711,
#   'Legislative District': 49.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': nan,
#   'cafv_type': nan,
#   'electric_utility': nan},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '7SAYGDEE9N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model Y',
#   'DOL Transaction Date': 'July 07 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'EDMONDS',
#   'Postal Code': 98026.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 205205836,
#   'Legislative District': 21.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 205205836.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB7N',
#   'Model Year': 2022,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'January 27 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 187319499,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 187319499.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJSA1E63M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model S',
#   'DOL Transaction Date': 'August 12 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 172467760,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 172467760.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'WA1F2AFY0M',
#   'Model Year': 2021,
#   'Make': 'AUDI',
#   'Model': 'Q5 e',
#   'DOL Transaction Date': 'December 02 2020',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2020,
#   'County': 'Kitsap',
#   'City': 'POULSBO',
#   'Postal Code': 98370.0,
#   'Electric Range': 18,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 135138216,
#   'Legislative District': 23.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 135138216.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'WDC0G5EB1K',
#   'Model Year': 2019,
#   'Make': 'MERCEDES-BENZ',
#   'Model': 'GLC-Class',
#   'DOL Transaction Date': 'February 15 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Whatcom',
#   'City': 'LYNDEN',
#   'Postal Code': 98264.0,
#   'Electric Range': 10,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 186891358,
#   'Legislative District': 42.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 186891358.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': '3MW5P9J06N',
#   'Model Year': 2022,
#   'Make': 'BMW',
#   'Model': '330e',
#   'DOL Transaction Date': 'December 22 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Pierce',
#   'City': 'LAKE TAPPS',
#   'Postal Code': 98391.0,
#   'Electric Range': 22,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 183392051,
#   'Legislative District': 31.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 183392051.0,
#   'cafv_type': 'Not eligible due to low battery range',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '1N4BZ1CV0M',
#   'Model Year': 2021,
#   'Make': 'NISSAN',
#   'Model': 'Leaf',
#   'DOL Transaction Date': 'April 18 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Pierce',
#   'City': 'TACOMA',
#   'Postal Code': 98405.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 198571397,
#   'Legislative District': 27.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 198571397.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': '5YJ3E1EB3M',
#   'Model Year': 2021,
#   'Make': 'TESLA',
#   'Model': 'Model 3',
#   'DOL Transaction Date': 'May 01 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'King',
#   'City': 'WOODINVILLE',
#   'Postal Code': 98072.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 148435682,
#   'Legislative District': 45.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 148435682.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'WVGUNPE2XM',
#   'Model Year': 2021,
#   'Make': 'VOLKSWAGEN',
#   'Model': 'ID.4',
#   'DOL Transaction Date': 'May 03 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Snohomish',
#   'City': 'BOTHELL',
#   'Postal Code': 98012.0,
#   'Electric Range': 0,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 198855436,
#   'Legislative District': 1.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 198855436.0,
#   'cafv_type': 'Eligibility unknown as battery range has not been researched',
#   'electric_utility': 'PUGET SOUND ENERGY INC'},
#  {'Clean Alternative Fuel Vehicle Type': 'Plug-in Hybrid Electric Vehicle (PHEV)',
#   'VIN (1-10)': 'WBY1Z8C36H',
#   'Model Year': 2017,
#   'Make': 'BMW',
#   'Model': 'i3',
#   'DOL Transaction Date': 'April 07 2021',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2021,
#   'County': 'Whatcom',
#   'City': 'BELLINGHAM',
#   'Postal Code': 98229.0,
#   'Electric Range': 97,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 148381026,
#   'Legislative District': 40.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 148381026.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY'},
#  {'Clean Alternative Fuel Vehicle Type': 'Battery Electric Vehicle (BEV)',
#   'VIN (1-10)': 'WVWKR7AU9K',
#   'Model Year': 2019,
#   'Make': 'VOLKSWAGEN',
#   'Model': 'e-Golf',
#   'DOL Transaction Date': 'August 23 2022',
#   'Transaction Type': 'Original Registration',
#   'Transaction Year': 2022,
#   'County': 'Pierce',
#   'City': 'TACOMA',
#   'Postal Code': 98405.0,
#   'Electric Range': 125,
#   'Vehicle Primary Use': 'Passenger',
#   'State of Residence': 'WA',
#   'DOL Vehicle ID': 212366178,
#   'Legislative District': 27.0,
#   'Transportation Electrification Fee Paid': 'No',
#   'dol_vehicle_id': 212366178.0,
#   'cafv_type': 'Clean Alternative Fuel Vehicle Eligible',
#   'electric_utility': 'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY'},
#  ...]

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)


# Define the 'classDB' database in Mongo
db = client.ev_DB

db.titles.drop()

#collection = db['<<INSERT NAME OF COLLECTION>>']

collection = db['titles']

# Insert collection
collection.insert_many(merged_dict)
