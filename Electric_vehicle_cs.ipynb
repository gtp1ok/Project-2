# %% [markdown]
# ### Extract Transform Load(ETL)
#
# The project goal is to collect data to compare the proportions of the number of electrical vehicles in Washington state to the  number of available charging stations.
#
# ### Electrical Vehicle Title and Registration Activity-Data
#
# The data "Electric Vehicle Title and Registration Activity" for Washington state was extracted from the Data.WA.gov (https://data.wa.gov/ ) using API. The sodaPy library was used to extract the data from the Data.WA.gov using the Api token.The obtained data in the dictionary format was converted to dataframe and was saved to "Electric_vehicle_df".For the analysis, the Battery Electric Vehicle (BEV) was filtered from the column electrical_vehicle_type.Once the data was cleaned, it was stored to "new_EV_df".
#
# ### Alternate Fuel station-Data
#
# The data " Alternate Fuel"  for Washington state was extracted from the NREL site (https://developer.nrel.gov/).
# Using Api, the following fields: station_name, zip code, citywere populated. The final dataset was stored in the dataframe "charging_station_df".
#
#
# The dataframe ""new_EV_df" and "charging_station_df" were merged into one dataframe "evehicle_cs_data".
#
# The data was loaded into MongoDB.

# %%
#import dependencies
import os
import requests
import json
import pandas as pd
import numpy as np
from api_keys import SODAPY_APPTOKEN, api_key
from sodapy import Socrata
import pymongo

# %% [markdown]
# ### Store the Electric_Vehicle_Title_and_Registration_Activity API into Dataframe

# %%
#getting the domain and data_identifier
#https://data.wa.gov/resource/rpr4-cgyd.json?electric_vehicle_type=Battery Electric Vehicle (BEV)
#https://dev.socrata.com/foundry/data.wa.gov/rpr4-cgyd-Api keys

socrata_domain = 'data.wa.gov'
socrata_dataset_identifier = 'rpr4-cgyd'


#  export SODAPY_APPTOKEN
socrata_token = os.environ.get("SODAPY_APPTOKEN")

# %%
#get the link
client = Socrata(socrata_domain, socrata_token)
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: data.wa.gov
# Session: <requests.sessions.Session object at 0x000001E950487F10>
# URI Prefix: https://

# %%
#store the data into dataframe
results = client.get(socrata_dataset_identifier)
Electric_vehicle_df = pd.DataFrame.from_dict(results)
Electric_vehicle_df.head()
# Out:
#                     electric_vehicle_type    vin_1_10 model_year  make  \
# 0          Battery Electric Vehicle (BEV)  WMWXP3C0XM       2021  MINI
# 1  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J       2018   KIA
# 2  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J       2018   KIA
# 3  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J       2018   KIA
# 4  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J       2018   KIA
#
#      model new_or_used_vehicle sale_price         transaction_date  \
# 0  Hardtop                Used          0  2022-08-04T00:00:00.000
# 1     Niro                Used          0  2021-11-19T00:00:00.000
# 2     Niro                 New      26999  2018-12-31T00:00:00.000
# 3     Niro                 New          0  2018-12-31T00:00:00.000
# 4     Niro                Used          0  2019-12-23T00:00:00.000
#
#         transaction_type transaction_year  ...  \
# 0   Registration Renewal             2022  ...
# 1   Registration Renewal             2021  ...
# 2         Original Title             2018  ...
# 3  Original Registration             2018  ...
# 4   Registration Renewal             2019  ...
#
#   hb_2042_clean_alternative_fuel_vehicle_cafv_eligibility  \
# 0  TRANSACTION NOT ELIGIBLE: Non-sale, registrati...
# 1  VEHICLE MODEL NOT ELIGIBLE: Low battery range;...
# 2  VEHICLE MODEL NOT ELIGIBLE: Low battery range;...
# 3  VEHICLE MODEL NOT ELIGIBLE: Low battery range;...
# 4  VEHICLE MODEL NOT ELIGIBLE: Low battery range;...
#
#   meets_2019_hb_2042_electric_range_requirement  \
# 0                                          True
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   meets_2019_hb_2042_sale_date_requirement  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   meets_2019_hb_2042_sale_price_value_requirement odometer_reading  \
# 0                                           False                0
# 1                                           False                0
# 2                                            True               17
# 3                                           False                0
# 4                                           False                0
#
#                                        odometer_code  \
# 0  Odometer reading is not collected at time of r...
# 1  Odometer reading is not collected at time of r...
# 2                                     Actual Mileage
# 3  Odometer reading is not collected at time of r...
# 4  Odometer reading is not collected at time of r...
#
#   transportation_electrification_fee_paid  \
# 0                                     Yes
# 1                                      No
# 2                          Not Applicable
# 3                                      No
# 4                                      No
#
#   hybrid_vehicle_electrification_fee_paid census_tract_2020  \
# 0                                      No       53033021906
# 1                                     Yes       53033002900
# 2                          Not Applicable       53033002900
# 3                                      No       53033002900
# 4                                     Yes       53033002900
#
#       date_of_vehicle_sale
# 0                      NaN
# 1                      NaN
# 2  2018-12-23T00:00:00.000
# 3                      NaN
# 4                      NaN
#
# [5 rows x 31 columns]

# %%
Electric_vehicle_df.columns.values
# Out:
# array(['electric_vehicle_type', 'vin_1_10', 'model_year', 'make', 'model',
#        'new_or_used_vehicle', 'sale_price', 'transaction_date',
#        'transaction_type', 'transaction_year',
#        'electric_vehicle_fee_paid', 'county', 'city', 'zip',
#        'electric_range', 'base_msrp', 'non_clean_alternative_fuel',
#        'vehicle_primary_use', 'state_of_residence', 'dol_vehicle_id',
#        'legislative_district',
#        'hb_2042_clean_alternative_fuel_vehicle_cafv_eligibility',
#        'meets_2019_hb_2042_electric_range_requirement',
#        'meets_2019_hb_2042_sale_date_requirement',
#        'meets_2019_hb_2042_sale_price_value_requirement',
#        'odometer_reading', 'odometer_code',
#        'transportation_electrification_fee_paid',
#        'hybrid_vehicle_electrification_fee_paid', 'census_tract_2020',
#        'date_of_vehicle_sale'], dtype=object)

# %%
EV_df = Electric_vehicle_df[["electric_vehicle_type", "vin_1_10","make", "model_year","vehicle_primary_use","county","city","zip","state_of_residence","transaction_type"]].copy()
EV_df.head()
# Out:
#                     electric_vehicle_type    vin_1_10  make model_year  \
# 0          Battery Electric Vehicle (BEV)  WMWXP3C0XM  MINI       2021
# 1  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J   KIA       2018
# 2  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J   KIA       2018
# 3  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J   KIA       2018
# 4  Plug-in Hybrid Electric Vehicle (PHEV)  KNDCM3LD1J   KIA       2018
#
#   vehicle_primary_use county         city    zip state_of_residence  \
# 0           Passenger   King  WOODINVILLE  98072                 WA
# 1           Passenger   King      SEATTLE  98103                 WA
# 2           Passenger   King      SEATTLE  98103                 WA
# 3           Passenger   King      SEATTLE  98103                 WA
# 4           Passenger   King      SEATTLE  98103                 WA
#
#         transaction_type
# 0   Registration Renewal
# 1   Registration Renewal
# 2         Original Title
# 3  Original Registration
# 4   Registration Renewal

# %%
orignal_df = EV_df[(EV_df["electric_vehicle_type"]=="Battery Electric Vehicle (BEV)")&(EV_df["transaction_type"]=="Original Registration")]
orignal_df
# Out:
#               electric_vehicle_type    vin_1_10       make model_year  \
# 8    Battery Electric Vehicle (BEV)  5YJ3E1EA3J      TESLA       2018
# 14   Battery Electric Vehicle (BEV)  5YJ3E1EC9N      TESLA       2022
# 17   Battery Electric Vehicle (BEV)  1G1FZ6S00K  CHEVROLET       2019
# 24   Battery Electric Vehicle (BEV)  1N4AZ0CP4D     NISSAN       2013
# 29   Battery Electric Vehicle (BEV)  JN1AZ0CP8B     NISSAN       2011
# ..                              ...         ...        ...        ...
# 964  Battery Electric Vehicle (BEV)  5YJYGDEE7M      TESLA       2021
# 968  Battery Electric Vehicle (BEV)  5YJXCBE24K      TESLA       2019
# 975  Battery Electric Vehicle (BEV)  1N4BZ0CP6G     NISSAN       2016
# 980  Battery Electric Vehicle (BEV)  5YJ3E1EB1K      TESLA       2019
# 995  Battery Electric Vehicle (BEV)  JN1AZ0CP0B     NISSAN       2011
#
#     vehicle_primary_use     county      city    zip state_of_residence  \
# 8             Passenger       King  KIRKLAND  98034                 WA
# 14            Passenger       King  BELLEVUE  98006                 WA
# 17            Passenger       King  BELLEVUE  98006                 WA
# 24            Passenger  Snohomish  LYNNWOOD  98087                 WA
# 29            Passenger  Snohomish  LYNNWOOD  98087                 WA
# ..                  ...        ...       ...    ...                ...
# 964           Passenger       King   SEATTLE  98103                 WA
# 968           Passenger       King    RENTON  98059                 WA
# 975           Passenger       King  KIRKLAND  98033                 WA
# 980           Passenger       King  KIRKLAND  98033                 WA
# 995           Passenger       King  BELLEVUE  98006                 WA
#
#           transaction_type
# 8    Original Registration
# 14   Original Registration
# 17   Original Registration
# 24   Original Registration
# 29   Original Registration
# ..                     ...
# 964  Original Registration
# 968  Original Registration
# 975  Original Registration
# 980  Original Registration
# 995  Original Registration
#
# [178 rows x 10 columns]

# %%
new_EV_df = orignal_df.drop(['transaction_type'], axis=1)
new_EV_df
# Out:
#               electric_vehicle_type    vin_1_10       make model_year  \
# 8    Battery Electric Vehicle (BEV)  5YJ3E1EA3J      TESLA       2018
# 14   Battery Electric Vehicle (BEV)  5YJ3E1EC9N      TESLA       2022
# 17   Battery Electric Vehicle (BEV)  1G1FZ6S00K  CHEVROLET       2019
# 24   Battery Electric Vehicle (BEV)  1N4AZ0CP4D     NISSAN       2013
# 29   Battery Electric Vehicle (BEV)  JN1AZ0CP8B     NISSAN       2011
# ..                              ...         ...        ...        ...
# 964  Battery Electric Vehicle (BEV)  5YJYGDEE7M      TESLA       2021
# 968  Battery Electric Vehicle (BEV)  5YJXCBE24K      TESLA       2019
# 975  Battery Electric Vehicle (BEV)  1N4BZ0CP6G     NISSAN       2016
# 980  Battery Electric Vehicle (BEV)  5YJ3E1EB1K      TESLA       2019
# 995  Battery Electric Vehicle (BEV)  JN1AZ0CP0B     NISSAN       2011
#
#     vehicle_primary_use     county      city    zip state_of_residence
# 8             Passenger       King  KIRKLAND  98034                 WA
# 14            Passenger       King  BELLEVUE  98006                 WA
# 17            Passenger       King  BELLEVUE  98006                 WA
# 24            Passenger  Snohomish  LYNNWOOD  98087                 WA
# 29            Passenger  Snohomish  LYNNWOOD  98087                 WA
# ..                  ...        ...       ...    ...                ...
# 964           Passenger       King   SEATTLE  98103                 WA
# 968           Passenger       King    RENTON  98059                 WA
# 975           Passenger       King  KIRKLAND  98033                 WA
# 980           Passenger       King  KIRKLAND  98033                 WA
# 995           Passenger       King  BELLEVUE  98006                 WA
#
# [178 rows x 9 columns]

# %%
new_EV_df.count()
# Out:
# electric_vehicle_type    178
# vin_1_10                 178
# make                     178
# model_year               178
# vehicle_primary_use      178
# county                   178
# city                     178
# zip                      178
# state_of_residence       178
# dtype: int64

# %%
new_EV_df['vehicle_primary_use'].value_counts()
# Out:
# Passenger    176
# Truck          2
# Name: vehicle_primary_use, dtype: int64

# %%
new_EV_df['electric_vehicle_type'].value_counts()
# Out:
# Battery Electric Vehicle (BEV)    178
# Name: electric_vehicle_type, dtype: int64

# %%
new_EV_df['make'].value_counts()
# Out:
# TESLA         102
# NISSAN         36
# CHEVROLET       8
# FORD            5
# KIA             5
# BMW             4
# VOLKSWAGEN      3
# VOLVO           3
# HYUNDAI         3
# POLESTAR        2
# MINI            2
# PORSCHE         1
# SMART           1
# FIAT            1
# RIVIAN          1
# AUDI            1
# Name: make, dtype: int64

# %%
new_EV_df['county'].value_counts()
# Out:
# King         140
# Snohomish     17
# Clark         10
# Thurston       5
# Kitsap         4
# Cowlitz        1
# Pierce         1
# Name: county, dtype: int64

# %% [markdown]
# ### Store Alternate fuel data from NREL API to Dataframe

# %%
# Calling the data from the site "https://developer.nrel.gov" using api key
target_url = f"https://developer.nrel.gov/api/alt-fuel-stations/v1.json?ELEC&state=WA&api_key=api_keys"

# %%
# Run a request to endpoint and convert result to json
Electric_charging_data = requests.get(target_url).json()

# Print the json
print(len(Electric_charging_data["fuel_stations"]))
#print(Electric_charging_data["fuel_stations"]["city"])
# Out:
# 2053

# %%
#for loop to get the desired column from the api
CS_data=[]
for i in range(len(Electric_charging_data["fuel_stations"])):
    
    zip_code = Electric_charging_data["fuel_stations"][i]["zip"]
    city = Electric_charging_data["fuel_stations"][i]["city"]
    station_name = Electric_charging_data["fuel_stations"][i]["station_name"]
    state = Electric_charging_data["fuel_stations"][i]["state"]
    
    # Append the City information into city_data list
    CS_data.append({"zip_code": zip_code, 
                    "city": city,
                    "state":state,
                    "station_name": station_name})

# %%
# Convert array of dictionaries to a pandas DataFrame.
charging_station_df = pd.DataFrame(CS_data)
charging_station_df.head(50)
# Out:
#    zip_code          city state  \
# 0     99163       Pullman    WA
# 1     99202       Spokane    WA
# 2     99403     Clarkston    WA
# 3     98233    Burlington    WA
# 4     98277    Oak Harbor    WA
# 5     98856         Twisp    WA
# 6     98902        Yakima    WA
# 7     98901        Yakima    WA
# 8     98930     Grandview    WA
# 9     98271    Marysville    WA
# 10    98248      Ferndale    WA
# 11    98296     Snohomish    WA
# 12    99141  Kettle Falls    WA
# 13    99202       Spokane    WA
# 14    98271    Marysville    WA
# 15    98264        Lynden    WA
# 16    98841          Omak    WA
# 17    98002        Auburn    WA
# 18    98028       Kenmore    WA
# 19    98036      Lynnwood    WA
# 20    98107       Ballard    WA
# 21    98118       Seattle    WA
# 22    98126       Seattle    WA
# 23    98133     Shoreline    WA
# 24    98198        SeaTac    WA
# 25    98203       Everett    WA
# 26    98226    Bellingham    WA
# 27    98405        Tacoma    WA
# 28    98444        Tacoma    WA
# 29    98506       Olympia    WA
# 30    98632      Longview    WA
# 31    98661     Vancouver    WA
# 32    98661     Vancouver    WA
# 33    98665     Vancouver    WA
# 34    98901        Yakima    WA
# 35    99204       Spokane    WA
# 36    99216       Spokane    WA
# 37    99218       Spokane    WA
# 38    99301         Pasco    WA
# 39    98107       Seattle    WA
# 40    98438        Tacoma    WA
# 41    98188        SeaTac    WA
# 42    98245     Eastsound    WA
# 43    98433    Fort Lewis    WA
# 44    99354      Richland    WA
# 45    98438        Tacoma    WA
# 46    98290     Snohomish    WA
# 47    98271    Marysville    WA
# 48    98503         Lacey    WA
# 49    98188       Seattle    WA
#
#                                          station_name
# 0                       Avista Pullman Service Center
# 1                   Avista Central Operating Facility
# 2                     Avista Clarkston Service Center
# 3                            Burlington Country Store
# 4                        Skagit Farmers Country Store
# 5                                  Hank's Mini Market
# 6                                            AmeriGas
# 7                            All American Propane Inc
# 8                                        Bleyhl Co-op
# 9                                    Suburban Propane
# 10                                      Starvin Sam's
# 11                                True Value Hardware
# 12                                           AmeriGas
# 13                                           AmeriGas
# 14                              American Distributing
# 15                        Northwest Propane Sales Inc
# 16                                  Omak Travel Plaza
# 17                                             U-Haul
# 18                                             U-Haul
# 19                                             U-Haul
# 20                                             U-Haul
# 21                                             U-Haul
# 22                                             U-Haul
# 23                                             U-Haul
# 24                                             U-Haul
# 25                                             U-Haul
# 26                                             U-Haul
# 27                                             U-Haul
# 28                                             U-Haul
# 29                                             U-Haul
# 30                                             U-Haul
# 31                                             U-Haul
# 32                                             U-Haul
# 33                                             U-Haul
# 34                                             U-Haul
# 35                                             U-Haul
# 36                                             U-Haul
# 37                                             U-Haul
# 38                                             U-Haul
# 39                  Dr. Dan's Alternative Fuels Werks
# 40                             McChord Air Force Base
# 41  Clean Energy - Seattle-Tacoma International Ai...
# 42                       Island Supply - Mead Biofuel
# 43                                         Fort Lewis
# 44                                      Pacific Pride
# 45                             McChord Air Force Base
# 46                                    Snohomish Co-op
# 47                                              Shell
# 48                  City of Lacey - City Hall Parking
# 49  Seattle-Tacoma International Airport - General...

# %%
charging_station_df['city'].value_counts()
# Out:
# Seattle                     484
# Bellevue                    198
# Tacoma                       97
# Vancouver                    59
# Spokane                      57
#                            ...
# Westport                      1
# Union                         1
# Stevenson                     1
# Seaview                       1
# Joint Base Lewis-McChord      1
# Name: city, Length: 218, dtype: int64

# %%
charging_station_df['zip_code'].value_counts()
# Out:
# 98004    117
# 98121     99
# 98109     78
# 98005     50
# 99354     49
#         ...
# 98595      1
# 98648      1
# 98644      1
# 98564      1
# 98592      1
# Name: zip_code, Length: 318, dtype: int64

# %%
charging_station_df.count()
# Out:
# zip_code        2053
# city            2053
# state           2053
# station_name    2053
# dtype: int64

# %% [markdown]
# ### Merge the data form Electric_vehicle_data and charging_station_df into one Dataframe

# %%
evehicle_cs_data=pd.merge(new_EV_df,charging_station_df,left_on='zip', right_on='zip_code',how='inner')
evehicle_cs_data
# Out:
#                electric_vehicle_type    vin_1_10    make model_year  \
# 0     Battery Electric Vehicle (BEV)  5YJ3E1EA3J   TESLA       2018
# 1     Battery Electric Vehicle (BEV)  5YJ3E1EA3J   TESLA       2018
# 2     Battery Electric Vehicle (BEV)  5YJ3E1EA3J   TESLA       2018
# 3     Battery Electric Vehicle (BEV)  5YJ3E1EA3J   TESLA       2018
# 4     Battery Electric Vehicle (BEV)  5YJ3E1EA3J   TESLA       2018
# ...                              ...         ...     ...        ...
# 1878  Battery Electric Vehicle (BEV)  1N4AZ0CP7F  NISSAN       2015
# 1879  Battery Electric Vehicle (BEV)  1N4AZ0CPXD  NISSAN       2013
# 1880  Battery Electric Vehicle (BEV)  1N4AZ0CPXD  NISSAN       2013
# 1881  Battery Electric Vehicle (BEV)  1N4AZ0CPXD  NISSAN       2013
# 1882  Battery Electric Vehicle (BEV)  1N4AZ0CPXD  NISSAN       2013
#
#      vehicle_primary_use county    city_x    zip state_of_residence zip_code  \
# 0              Passenger   King  KIRKLAND  98034                 WA    98034
# 1              Passenger   King  KIRKLAND  98034                 WA    98034
# 2              Passenger   King  KIRKLAND  98034                 WA    98034
# 3              Passenger   King  KIRKLAND  98034                 WA    98034
# 4              Passenger   King  KIRKLAND  98034                 WA    98034
# ...                  ...    ...       ...    ...                ...      ...
# 1878           Passenger   King   REDMOND  98053                 WA    98053
# 1879           Passenger   King   KENMORE  98028                 WA    98028
# 1880           Passenger   King   KENMORE  98028                 WA    98028
# 1881           Passenger   King   KENMORE  98028                 WA    98028
# 1882           Passenger   King   KENMORE  98028                 WA    98028
#
#         city_y state                            station_name
# 0     Kirkland    WA          Alliance AutoGas - Kirkland 76
# 1     Kirkland    WA            MAIN HOSPITAL SILVER PARKING
# 2     Kirkland    WA                  MAIN HOSPITAL DEYOUNG1
# 3     Kirkland    WA              MAIN HOSPITAL BLUE PARKING
# 4     Kirkland    WA                 MAIN HOSPITAL SILVER #2
# ...        ...   ...                                     ...
# 1878   Redmond    WA  Albertsons 3925236Th Ave NE Redmond WA
# 1879   Kenmore    WA                                  U-Haul
# 1880   Kenmore    WA                           Safeway #3500
# 1881   Kenmore    WA                 Lodge at St Edward Park
# 1882   Kenmore    WA                    The Hanger - Kenmore
#
# [1883 rows x 13 columns]

# %% [markdown]
# ### Loadd the data to Database

# %%
# Convert dataframe to dictinary
dict_data=evehicle_cs_data.to_dict("records")
dict_data
# Out:
# [{'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Alliance AutoGas - Kirkland 76'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL DEYOUNG1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL BLUE PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lake Washington Institute of Technology'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Walgreens - Kirkland, WA #6258'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Emerson Apartments'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'QFC 828 (Kirkland, WA)'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Volkswagen of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'BELL TOTEM LAKE STATION 5 41-42'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland -  East Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland - West Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'King County Housing Authority - Juanita Court'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA3J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'ASPECT ASPCT AT TOTEM'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Alliance AutoGas - Kirkland 76'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL DEYOUNG1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL BLUE PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lake Washington Institute of Technology'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Walgreens - Kirkland, WA #6258'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Emerson Apartments'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'QFC 828 (Kirkland, WA)'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Volkswagen of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'BELL TOTEM LAKE STATION 5 41-42'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland -  East Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland - West Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'King County Housing Authority - Juanita Court'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FY6S03L',
#   'make': 'CHEVROLET',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'ASPECT ASPCT AT TOTEM'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Alliance AutoGas - Kirkland 76'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL DEYOUNG1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL BLUE PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lake Washington Institute of Technology'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Walgreens - Kirkland, WA #6258'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Emerson Apartments'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'QFC 828 (Kirkland, WA)'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Volkswagen of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'BELL TOTEM LAKE STATION 5 41-42'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland -  East Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland - West Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'King County Housing Authority - Juanita Court'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1FADP3R41D',
#   'make': 'FORD',
#   'model_year': '2013',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'ASPECT ASPCT AT TOTEM'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Alliance AutoGas - Kirkland 76'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL DEYOUNG1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL BLUE PARKING'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'MAIN HOSPITAL SILVER #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lake Washington Institute of Technology'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Walgreens - Kirkland, WA #6258'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Emerson Apartments'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'QFC 828 (Kirkland, WA)'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Volkswagen of Kirkland'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'BELL TOTEM LAKE STATION 5 41-42'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland -  East Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lifebridge-Uplund Kirkland - West Building'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'Lee Johnson Nissan'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'King County Housing Authority - Juanita Court'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FW6S02H',
#   'make': 'CHEVROLET',
#   'model_year': '2017',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'KIRKLAND',
#   'zip': '98034',
#   'state_of_residence': 'WA',
#   'zip_code': '98034',
#   'city_y': 'Kirkland',
#   'state': 'WA',
#   'station_name': 'ASPECT ASPCT AT TOTEM'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EC9N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1G1FZ6S00K',
#   'make': 'CHEVROLET',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': 'KNDCE3LGXL',
#   'make': 'KIA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CP2J',
#   'make': 'NISSAN',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EBXK',
#   'make': 'TESLA',
#   'model_year': '2019',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EB8L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'E_SOFI SOFI #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'SRO SP1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'AMC Factoria 8'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'BELLEVUE SBCC #1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': 'The Marketplace at Factoria'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '7SAYGDEE3N',
#   'make': 'TESLA',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'BELLEVUE',
#   'zip': '98006',
#   'state_of_residence': 'WA',
#   'zip_code': '98006',
#   'city_y': 'Bellevue',
#   'state': 'WA',
#   'station_name': '531631 - HQ Building 2 - P2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJXCBE24J',
#   'make': 'TESLA',
#   'model_year': '2018',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
# ...
#   'station_name': 'Madison Miller'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA9L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'LAWRENCE LOFTS LL COMMERCIAL'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA9L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Harvard Market'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJ3E1EA9L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Whole Foods Madison Broadway'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Central Co-op'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': '531604 : 600 Broadway'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'P1 Parking Level 1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'BROADWAY BLDG STATION 1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Viva Apartment Homes'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Madison Pike WA3-141 ( Seattle, WA)'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Harvard Market'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Pike Motorworks'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'DC CORRIDOR CENTRAL SEA COL'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Madison Miller'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'LAWRENCE LOFTS LL COMMERCIAL'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Harvard Market'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE5L',
#   'make': 'TESLA',
#   'model_year': '2020',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Whole Foods Madison Broadway'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Central Co-op'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': '531604 : 600 Broadway'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'P1 Parking Level 1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'BROADWAY BLDG STATION 1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Viva Apartment Homes'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Madison Pike WA3-141 ( Seattle, WA)'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Harvard Market'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Pike Motorworks'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'DC CORRIDOR CENTRAL SEA COL'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Madison Miller'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'LAWRENCE LOFTS LL COMMERCIAL'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Harvard Market'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ0CP4F',
#   'make': 'NISSAN',
#   'model_year': '2015',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'SEATTLE',
#   'zip': '98122',
#   'state_of_residence': 'WA',
#   'zip_code': '98122',
#   'city_y': 'Seattle',
#   'state': 'WA',
#   'station_name': 'Whole Foods Madison Broadway'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'ESSEX HIGHLANDS'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'Fred Meyer - Tesla Supercharger'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'ISD411 ADMIN CENTER 1'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'Grand Ridge Plaza'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'Discovery West Apartments'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'KING COUNTY DOT ISSAQUAH P&R 6'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'KING COUNTY DOT ISSAQUAH P&R 5'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'ISD411 ADMIN CENTER 2'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'KING COUNTY DOT ISSAQUAH P&R 7'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'KING COUNTY DOT ISSAQUAH P&R 4'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '5YJYGDEE3M',
#   'make': 'TESLA',
#   'model_year': '2021',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'King',
#   'city_x': 'ISSAQUAH',
#   'zip': '98029',
#   'state_of_residence': 'WA',
#   'zip_code': '98029',
#   'city_y': 'Issaquah',
#   'state': 'WA',
#   'station_name': 'KING COUNTY DOT ISSAQUAH P&R 3'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CVXN',
#   'make': 'NISSAN',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'Snohomish',
#   'city_x': 'SNOHOMISH',
#   'zip': '98290',
#   'state_of_residence': 'WA',
#   'zip_code': '98290',
#   'city_y': 'Snohomish',
#   'state': 'WA',
#   'station_name': 'Snohomish Co-op'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CVXN',
#   'make': 'NISSAN',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'Snohomish',
#   'city_x': 'SNOHOMISH',
#   'zip': '98290',
#   'state_of_residence': 'WA',
#   'zip_code': '98290',
#   'city_y': 'Snohomish',
#   'state': 'WA',
#   'station_name': 'KOZ WEAVER WEAVER RD RIGHT'},
#  {'electric_vehicle_type': 'Battery Electric Vehicle (BEV)',
#   'vin_1_10': '1N4AZ1CVXN',
#   'make': 'NISSAN',
#   'model_year': '2022',
#   'vehicle_primary_use': 'Passenger',
#   'county': 'Snohomish',
#   'city_x': 'SNOHOMISH',
#   'zip': '98290',
#   'state_of_residence': 'WA',
#   'zip_code': '98290',
#   'city_y': 'Snohomish',
#   'state': 'WA',
#   'station_name': 'KOZ WEAVER WEAVER RD MIDDL'},
#  ...]

# %%
# create a table and collection in mongoDB 
#drop the data into the database
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the 'classDB' database in Mongo
db = client.ev_cs_DB
#drop the collection if exists
db.table.drop()

#collection 

collection = db['table']

# Insert collection
collection.insert_many(dict_data)
